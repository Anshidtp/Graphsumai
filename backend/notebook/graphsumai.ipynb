# %%
import pandas as pd
from neo4j import GraphDatabase
from tqdm import tqdm

# %%
# %pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from tqdm) (0.4.6)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
DATA_PATH = "../data/raw/"

TRAIN_FILE = DATA_PATH + "train.txt"
VALID_FILE = DATA_PATH + "valid.txt"
TEST_FILE  = DATA_PATH + "test.txt"

# %%
def load_triples(path):
    df = pd.read_csv(path, sep="\t", header=None)
    df.columns = ["head", "relation", "tail"]
    return df

train_df = load_triples(TRAIN_FILE)
valid_df = load_triples(VALID_FILE)
test_df  = load_triples(TEST_FILE)

train_df.head()
# Out:
#          head                                           relation       tail
# 0    /m/027rn               /location/country/form_of_government   /m/06cx9
# 1   /m/017dcd  /tv/tv_program/regular_cast./tv/regular_tv_app...  /m/06v8s0
# 2  /m/07s9rl0                 /media_common/netflix_genre/titles  /m/0170z3
# 3   /m/01sl1q  /award/award_winner/awards_won./award/award_ho...  /m/044mz_
# 4   /m/0cnk2q  /soccer/football_team/current_roster./sports/s...  /m/02nzb8

# %%
print("Train triples:", len(train_df))
print("Valid triples:", len(valid_df))
print("Test triples:", len(test_df))

print("Unique entities:", pd.concat([
    train_df["head"], train_df["tail"]
]).nunique())

print("Unique relations:", train_df["relation"].nunique())
# Out:
# Train triples: 272115
# Valid triples: 17535
# Test triples: 20466
# Unique entities: 14505
# Unique relations: 237

# %%
import os
from dotenv import load_dotenv

load_dotenv()

NEO4J_URI = os.getenv("NEO4J_URI")
USERNAME = os.getenv("USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

driver = GraphDatabase.driver(
    "neo4j+s://cb4b49e2.databases.neo4j.io",
    auth=("neo4j", "nq5V7b0rJ4a9MvY3_ldBgHQQ4D1H3kdoMeWOXk1VaIM")
)
# Out:
# python-dotenv could not parse statement starting at line 2

# %%
# %pip install langchain langchain-community langchain-neo4j
# Out:
# Requirement already satisfied: langchain in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (1.2.0)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-neo4j in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (0.6.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain) (1.2.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-community) (2.0.45)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.2-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-community) (2.12.0)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-community) (2.3.5)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: neo4j<6.0.0,>=5.25.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-neo4j) (5.28.2)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.9.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from langchain-neo4j) (1.11.0)
# Requirement already satisfied: pytz in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j<6.0.0,>=5.25.0->langchain-neo4j) (2025.2)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j) (2024.12.0)
# Requirement already satisfied: json-repair<0.45.0,>=0.44.1 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j) (0.44.1)
# Requirement already satisfied: pypdf<7.0.0,>=6.0.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j) (6.5.0)
# Requirement already satisfied: scipy<2.0.0,>=1.15.0 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j) (1.16.3)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in c:\users\lenovo\anaconda3\envs\graph\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j) (6.0.12.20250915)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 1.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.3 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.4 MB/s  0:00:01
# Downloading aiohttp-3.13.2-cp313-cp313-win_amd64.whl (452 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Installing collected packages: propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, dataclasses-json, aiohttp, langchain-community
#
#    ----- ----------------------------------  2/14 [multidict]
#    -------- -------------------------------  3/14 [marshmallow]
#    ----------------- ----------------------  6/14 [attrs]
#    ----------------- ----------------------  6/14 [attrs]
#    ---------------------- -----------------  8/14 [yarl]
#    ---------------------------- ----------- 10/14 [aiosignal]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ---------------------------------------- 14/14 [langchain-community]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 attrs-25.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-community-0.4.1 marshmallow-3.26.2 multidict-6.7.0 mypy-extensions-1.1.0 propcache-0.4.1 typing-inspect-0.9.0 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(refresh_schema=False,username="neo4j",
                    password="nq5V7b0rJ4a9MvY3_ldBgHQQ4D1H3kdoMeWOXk1VaIM",
                   url="neo4j+s://cb4b49e2.databases.neo4j.io")

# %%
def create_constraints():
    query = """
    CREATE CONSTRAINT IF NOT EXISTS
    FOR (e:Entity)
    REQUIRE e.name IS UNIQUE
    """
    with driver.session() as session:
        session.run(query)

create_constraints()

# %%
def load_to_neo4j(df, batch_size=1000):
    query = """
    UNWIND $rows AS row
    MERGE (h:Entity {name: row.head})
    MERGE (t:Entity {name: row.tail})
    MERGE (h)-[:RELATION {type: row.relation}]->(t)
    """

    with driver.session() as session:
        for i in tqdm(range(0, len(df), batch_size)):
            batch = df.iloc[i:i+batch_size].to_dict("records")
            session.run(query, rows=batch)

# %%
load_to_neo4j(train_df)
# Out:
# 100%|██████████| 273/273 [00:54<00:00,  5.03it/s]

# %%
with driver.session() as session:
    result = session.run("MATCH (n:Entity) RETURN count(n)")
    print(result.single())
# Out:
# <Record count(n)=14529>

# %%
query = """
MATCH (h:Entity)-[r]->(t:Entity)
RETURN h.name, r.type, t.name
LIMIT 10
"""

with driver.session() as session:
    for record in session.run(query):
        print(record)
# Out:
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>
# <Record h.name=None r.type=None t.name=None>

# %%
query = """
MATCH (p:Entity {name: "person"})-[r]->(x)
RETURN p.name, r.type, x.name
"""

with driver.session() as session:
    for r in session.run(query):
        print(r)
